# %%
from randan.descriptive_statistics import ScaleStatistics # интервальная статистика
import pandas as pd # для обработки и анализа структурированных данных
import numpy as np# для корректной работы рандана 
from randan.bivariate_association import Correlation

# %% [markdown]
# # Надежность-устойчивость: Гендерный индекс в области целей устойчивого развития организации "Равные меры — 2030" за 2015 и 2020 годы (Equal Measures — 2030)

# %% [markdown]
# Массив данных находится в папке: https://disk.yandex.ru/d/PWOTilngObaAJg
#
# Рейтинг за 2022 год: https://equalmeasures2030.org/2022-sdg-gender-index-report/#:~:text=Progress%20on%20gender%20equality%20has,the%20achievement%20of%20the%20SDGs.

# %%
# загружаем таблицу
df = pd.read_excel('esdg_15_20.xlsx')

# %%
# удаляем пробелы
df = df.dropna()
df
# Out:
#          country       2015       2020
# 0    Afghanistan  40.046421  38.166742
# 1        Albania  70.432066  74.188821
# 2        Algeria  65.617685  64.339099
# 4      Argentina  75.119741  74.514991
# 5        Armenia  67.602252  74.340911
# ..           ...        ...        ...
# 138   Uzbekistan  68.839980  69.442619
# 139    Venezuela  62.469646  55.781751
# 140     Viet Nam  67.166860  69.391586
# 142       Zambia  48.774654  50.440768
# 143     Zimbabwe  53.876147  53.034472
#
# [135 rows x 3 columns]

# %%
# в таблице 135 стран без пробелов в данных
# округляем значения
df = df.round(decimals=2)
df
# Out:
#          country   2015   2020
# 0    Afghanistan  40.05  38.17
# 1        Albania  70.43  74.19
# 2        Algeria  65.62  64.34
# 4      Argentina  75.12  74.51
# 5        Armenia  67.60  74.34
# ..           ...    ...    ...
# 138   Uzbekistan  68.84  69.44
# 139    Venezuela  62.47  55.78
# 140     Viet Nam  67.17  69.39
# 142       Zambia  48.77  50.44
# 143     Zimbabwe  53.88  53.03
#
# [135 rows x 3 columns]

# %%
# дескриптивная статистика
df.describe()
# Out:
#              2015        2020
# count  135.000000  135.000000
# mean    65.958741   67.791778
# std     13.330627   12.998867
# min     34.950000   35.630000
# 25%     56.035000   58.960000
# 50%     66.970000   68.750000
# 75%     76.070000   77.640000
# max     90.190000   90.420000

# %%
# проверяем нормальность распределения за 2020 год
# тест Колмогорова-Смирнова
ss = ScaleStatistics(df, [2020], show_results=False, normality_test=True, normality_test_type='ks') 
ss.summary()
# Out:
# NORMALITY TESTS
# ------------------
# <style type="text/css">
# </style>
# <table id="T_2cc31">
#   <caption>method .normality_test(test_type='ks')</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cc31_level0_col0" class="col_heading level0 col0" >statistic</th>
#       <th id="T_2cc31_level0_col1" class="col_heading level0 col1" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cc31_level0_row0" class="row_heading level0 row0" >2020</th>
#       <td id="T_2cc31_row0_col0" class="data row0 col0" >0.065</td>
#       <td id="T_2cc31_row0_col1" class="data row0 col1" >0.225</td>
#     </tr>
#   </tbody>
# </table>
#           N   mode  median       mean    25%    75%  interquart. range  \
# 2020  135.0  35.63   68.75  67.791778  58.96  77.64              18.68
#
#       interquart. range (norm.)    min    max  range        std         var  \
# 2020                   0.340938  35.63  90.42  54.79  12.998867  168.970542
#
#       entropy coef.  quality var.
# 2020            1.0           1.0

# %% [markdown]
# Распределение данных за 2020 год не является нормальным. Применим метод Спирмена (как и для остальных рейтингов) для корреляционного анализа.

# %%
# корреляционный анализ значений рейтинга по годам, метод Пирсона
corr = Correlation(df, method = 'spearman', two_tailed = False, n_decimals=3)
# Out:
# CORRELATION SUMMARY (SPEARMAN METHOD, 1-TAILED)
# ------------------
# The following variables were removed from the analysis since they do not belong to numerical dtypes: country
# <style type="text/css">
# </style>
# <table id="T_ae435">
#   <caption>attribute .correlation_matrix</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae435_level0_col0" class="col_heading level0 col0" >2015</th>
#       <th id="T_ae435_level0_col1" class="col_heading level0 col1" >2020</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae435_level0_row0" class="row_heading level0 row0" rowspan="3">2015</th>
#       <th id="T_ae435_level1_row0" class="row_heading level1 row0" >Coefficient</th>
#       <td id="T_ae435_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_ae435_row0_col1" class="data row0 col1" >0.988</td>
#     </tr>
#     <tr>
#       <th id="T_ae435_level1_row1" class="row_heading level1 row1" >p-value</th>
#       <td id="T_ae435_row1_col0" class="data row1 col0" ></td>
#       <td id="T_ae435_row1_col1" class="data row1 col1" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_ae435_level1_row2" class="row_heading level1 row2" >N</th>
#       <td id="T_ae435_row2_col0" class="data row2 col0" >135.000</td>
#       <td id="T_ae435_row2_col1" class="data row2 col1" >135.000</td>
#     </tr>
#     <tr>
#       <th id="T_ae435_level0_row3" class="row_heading level0 row3" rowspan="3">2020</th>
#       <th id="T_ae435_level1_row3" class="row_heading level1 row3" >Coefficient</th>
#       <td id="T_ae435_row3_col0" class="data row3 col0" >0.988</td>
#       <td id="T_ae435_row3_col1" class="data row3 col1" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_ae435_level1_row4" class="row_heading level1 row4" >p-value</th>
#       <td id="T_ae435_row4_col0" class="data row4 col0" >0.000</td>
#       <td id="T_ae435_row4_col1" class="data row4 col1" ></td>
#     </tr>
#     <tr>
#       <th id="T_ae435_level1_row5" class="row_heading level1 row5" >N</th>
#       <td id="T_ae435_row5_col0" class="data row5 col0" >135.000</td>
#       <td id="T_ae435_row5_col1" class="data row5 col1" >135.000</td>
#     </tr>
#   </tbody>
# </table>
# Note: Each empty index duplicates the previous one.
# Maximum correlation is 0.988 (p-value 0.0) for variables 2015 and 2020,
# minimum correlation is 0.988 (p-value 0.0) for variables 2015 and 2020.

# %% [markdown]
# Значения коэффициента корреляции Спирмена составляет  0,988  при p-value менее 0,05. Рейтинг Гендерный индекс в области целей устойчивого развития организации "Равные меры — 2030" обладает высокой надежностью-устойчивостью.
